# %%
import pandas as pd
import os

# %%
file_name = "SalesOrderItems.csv"
folder_name = "Capstone_project"
percorso = os.getcwd()
salesorderitems = pd.read_csv(os.path.join(percorso,folder_name,file_name))

# %%
columns_to_drop = ["NOTEID", "CURRENCY", "OPITEMPOS", "QUANTITYUNIT"]
salesorderitems = salesorderitems.drop(columns=columns_to_drop)

# %%
salesorderitems.isna().any()
# Out:
# SALESORDERID      False
# SALESORDERITEM    False
# PRODUCTID         False
# GROSSAMOUNT       False
# NETAMOUNT         False
# TAXAMOUNT         False
# ITEMATPSTATUS     False
# QUANTITY          False
# DELIVERYDATE      False
# dtype: bool

# %%
salesorderitems.to_excel("SalesOrderItems.xlsx")

# %%
file_name = "Addresses.csv"
folder_name = "Capstone_project"
percorso = os.getcwd()
addresses = pd.read_csv(os.path.join(percorso,folder_name,file_name))

# %%
addresses.head()
# Out:
#     ADDRESSID        CITY POSTALCODE            STREET  BUILDING COUNTRY  \
# 0  1000000034  West Nyack      10994     Settlers Lane    5027.0      US
# 1  1000000035   Fair Oaks      95628  Woodland Terrace    4467.0      US
# 2  1000000036        Dunn      28334     Layman Avenue    2250.0      US
# 3  1000000037     Chicago      60605  University Drive    4697.0      US
# 4  1000000038       Ocala      34471    Bagwell Avenue    1565.0      US
#
#   REGION  ADDRESSTYPE  VALIDITY_STARTDATE  VALIDITY_ENDDATE   LATITUDE  \
# 0   AMER            2            20000101          99991231  41.100057
# 1   AMER            2            20000101          99991231  38.638355
# 2   AMER            2            20000101          99991231  35.312013
# 3   AMER            2            20000101          99991231  41.874591
# 4   AMER            2            20000101          99991231  29.183977
#
#     LONGITUDE
# 0  -73.973562
# 1 -121.286683
# 2  -78.609950
# 3  -87.627303
# 4  -82.118413

# %%
columns_to_drop = ["STREET", "BUILDING", "REGION", "ADDRESSTYPE", "VALIDITY_STARTDATE", "VALIDITY_ENDDATE"]
addresses = addresses.drop(columns=columns_to_drop)

# %%
addresses.head()
# Out:
#     ADDRESSID        CITY POSTALCODE COUNTRY   LATITUDE   LONGITUDE
# 0  1000000034  West Nyack      10994      US  41.100057  -73.973562
# 1  1000000035   Fair Oaks      95628      US  38.638355 -121.286683
# 2  1000000036        Dunn      28334      US  35.312013  -78.609950
# 3  1000000037     Chicago      60605      US  41.874591  -87.627303
# 4  1000000038       Ocala      34471      US  29.183977  -82.118413

# %%
addresses.isna().any()
# Out:
# ADDRESSID     False
# CITY          False
# POSTALCODE    False
# COUNTRY       False
# LATITUDE      False
# LONGITUDE     False
# dtype: bool

# %%
addresses.to_excel("Addresses.xlsx")

# %%
file_name = "BusinessPartners.csv"
folder_name = "Capstone_project"
percorso = os.getcwd()
businesspartners = pd.read_csv(os.path.join(percorso,folder_name,file_name))

# %%
businesspartners.head()
# Out:
#    PARTNERID  PARTNERROLE                      EMAILADDRESS  PHONENUMBER  \
# 0  100000000            2         maria.brown@all4bikes.com    622734567
# 1  100000001            2          bob.buyer@amazebikes.com      3088530
# 2  100000002            2  victor.sanchez@arenasportusa.com   3023352668
# 3  100000003            2     franklin.jones@atlantausa.com    511403266
# 4  100000004            2       robert_brown@bikeworlds.com   2244668800
#
#    FAXNUMBER                    WEBADDRESS   ADDRESSID       COMPANYNAME  \
# 0        NaN      http://www.all4bikes.com  1000000034     All For Bikes
# 1        NaN     http://www.amazebikes.com  1000000035   Amaze Bikes Inc
# 2        NaN  http://www.arenasportusa.com  1000000036  Arena Sports Inc
# 3        NaN     http://www.atlantausa.com  1000000037  Atlanta Corp Inc
# 4        NaN     http://www.bikeworlds.com  1000000038    Bike World Inc
#
#   LEGALFORM  CREATEDBY  CREATEDAT  CHANGEDBY  CHANGEDAT CURRENCY
# ...

# %%
columns_to_drop = ["PARTNERROLE", "EMAILADDRESS", "PHONENUMBER", "FAXNUMBER", "WEBADDRESS", "LEGALFORM", "CHANGEDBY", "CHANGEDAT", "CURRENCY"]
businesspartners = businesspartners.drop(columns=columns_to_drop)

# %%
businesspartners.head()
# Out:
#    PARTNERID   ADDRESSID       COMPANYNAME  CREATEDBY  CREATEDAT
# 0  100000000  1000000034     All For Bikes         10   20181003
# 1  100000001  1000000035   Amaze Bikes Inc         13   20181003
# 2  100000002  1000000036  Arena Sports Inc         14   20181003
# 3  100000003  1000000037  Atlanta Corp Inc         10   20181003
# 4  100000004  1000000038    Bike World Inc          4   20181003

# %%
businesspartners.isna().any()
# Out:
# PARTNERID      False
# ADDRESSID      False
# COMPANYNAME    False
# CREATEDBY      False
# CREATEDAT      False
# dtype: bool

# %%
businesspartners.to_excel("BusinessPartners.xlsx")

# %%
file_name = "Employees.csv"
folder_name = "Capstone_Project"
percorso = os.getcwd()
employees = pd.read_csv(os.path.join(percorso,folder_name,file_name), encoding="windows-1252")

# %%
employees.head()
# Out:
#    EMPLOYEEID NAME_FIRST NAME_MIDDLE  NAME_LAST  NAME_INITIALS SEX LANGUAGE  \
# 0           1    Derrick           L     Magill            NaN   M        E
# 1           2    Philipp           T      Egger            NaN   M        E
# 2           3      Ellis           K  Robertson            NaN   M        E
# 3           4    William           M     Mussen            NaN   M        E
# 4           5      Javas         NaN      Hegde            NaN   M        E
#
#       PHONENUMBER                EMAILADDRESS LOGINNAME   ADDRESSID  \
# 0    630-374-0306   derrick.magill@itelo.info  derrickm  1000000001
# 1  09603 61 24 64    philipp.egger@itelo.info  philippm  1000000002
# 2   070 8691 2288  ellis.robertson@itelo.info    ellism  1000000003
# 3     026734 4556   william.mussen@itelo.info  williamm  1000000004
# 4     02224135120      javas.hegde@itelo.info    javasm  1000000005
#
#    VALIDITY_STARTDATE  VALIDITY_ENDDATE  Unnamed: 13  Unnamed: 14  \
# ...

# %%
columns_to_drop = ["NAME_MIDDLE", "NAME_INITIALS", "LANGUAGE", "PHONENUMBER", "EMAILADDRESS", "LOGINNAME", "VALIDITY_STARTDATE", "VALIDITY_ENDDATE", "Unnamed: 13", "Unnamed: 14", "Unnamed: 15", "Unnamed: 16", "Unnamed: 17", "Unnamed: 18"]
employees = employees.drop(columns=columns_to_drop)

# %%
employees.head()
# Out:
#    EMPLOYEEID NAME_FIRST  NAME_LAST SEX   ADDRESSID
# 0           1    Derrick     Magill   M  1000000001
# 1           2    Philipp      Egger   M  1000000002
# 2           3      Ellis  Robertson   M  1000000003
# 3           4    William     Mussen   M  1000000004
# 4           5      Javas      Hegde   M  1000000005

# %%
employees.isna().any()
# Out:
# EMPLOYEEID    False
# NAME_FIRST    False
# NAME_LAST     False
# SEX           False
# ADDRESSID     False
# dtype: bool

# %%
employees.to_excel("Employees.xlsx")

# %%
file_name = "ProductCategories.csv"
folder_name = "Capstone_Project"
percorso = os.getcwd()
productcategories = pd.read_csv(os.path.join(percorso,folder_name,file_name))

# %%
productcategories.head()
# Out:
#   PRODCATEGORYID  CREATEDBY  CREATEDAT
# 0             RO         12   20181003
# 1             BX          4   20181003
# 2             CC          7   20181003
# 3             MB         11   20181003
# 4             RC          9   20181003

# %%
productcategories = productcategories.drop(columns="CREATEDAT")

# %%
productcategories.head()
# Out:
#   PRODCATEGORYID  CREATEDBY
# 0             RO         12
# 1             BX          4
# 2             CC          7
# 3             MB         11
# 4             RC          9

# %%
productcategories.isna().any()
# Out:
# PRODCATEGORYID    False
# CREATEDBY         False
# dtype: bool

# %%
productcategories.to_excel("ProductCategories.xlsx")

# %%
file_name = "ProductCategoryText.csv"
folder_name = "Capstone_Project"
percorso = os.getcwd()
productcategorytext = pd.read_csv(os.path.join(percorso,folder_name,file_name))

# %%
productcategorytext.head()
# Out:
#   PRODCATEGORYID LANGUAGE       SHORT_DESCR  MEDIUM_DESCR  LONG_DESCR
# 0             RO       EN         Road Bike           NaN         NaN
# 1             BX       EN               BMX           NaN         NaN
# 2             CC       EN  Cyclo-cross Bike           NaN         NaN
# 3             MB       EN     Mountain Bike           NaN         NaN
# 4             RC       EN       Racing Bike           NaN         NaN

# %%
columns_to_drop = ["LANGUAGE", "MEDIUM_DESCR", "LONG_DESCR"]
productcategorytext = productcategorytext.drop(columns=columns_to_drop)

# %%
productcategorytext.isna().any()
# Out:
# PRODCATEGORYID    False
# SHORT_DESCR       False
# dtype: bool

# %%
productcategorytext.to_excel("ProductCategoryText.xlsx")

# %%
file_name = "Products.csv"
folder_name = "Capstone_Project"
percorso = os.getcwd()
products = pd.read_csv(os.path.join(percorso,folder_name,file_name))

# %%
products.head()
# Out:
#   PRODUCTID TYPECODE PRODCATEGORYID  CREATEDBY  CREATEDAT  CHANGEDBY  \
# 0   RO-1001       PR             RO          9   20181003          9
# 1   RO-1002       PR             RO          9   20181003          9
# 2   RO-1003       PR             RO         12   20181003         12
# 3   BX-1011       PR             BX          9   20181003          9
# 4   BX-1012       PR             BX          6   20181003          6
#
#    CHANGEDAT  SUPPLIER_PARTNERID  TAXTARIFFCODE QUANTITYUNIT  WEIGHTMEASURE  \
# 0   20181003           100000000              1           EA            7.7
# 1   20181003           100000001              1           EA            8.0
# 2   20181003           100000002              1           EA            9.1
# 3   20181003           100000003              1           EA           11.1
# 4   20181003           100000004              1           EA           12.0
#
#   WEIGHTUNIT CURRENCY  PRICE  WIDTH  DEPTH  HEIGHT  DIMENSIONUNIT  \
# ...

# %%
columns_to_drop = ["TYPECODE", "CREATEDAT", "CHANGEDBY", "CHANGEDAT", "TAXTARIFFCODE", "QUANTITYUNIT", "WEIGHTUNIT", "CURRENCY", "WIDTH", "DEPTH", "HEIGHT", "DIMENSIONUNIT", "PRODUCTPICURL"]
products = products.drop(columns=columns_to_drop)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[223], line 2
#       1 columns_to_drop = ["TYPECODE", "CREATEDAT", "CHANGEDBY", "CHANGEDAT", "TAXTARIFFCODE", "QUANTITYUNIT", "WEIGHTUNIT", "CURRENCY", "WIDTH", "DEPTH", "HEIGHT", "DIMENSIONUNIT", "PRODUCTPICURL"]
# ----> 2 products = products.drop(columns=columns_to_drop)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
# ...

# %%
products.head()
# Out:
#   PRODUCTID PRODCATEGORYID  CREATEDBY  SUPPLIER_PARTNERID  WEIGHTMEASURE  \
# 0   RO-1001             RO          9           100000000            7.7
# 1   RO-1002             RO          9           100000001            8.0
# 2   RO-1003             RO         12           100000002            9.1
# 3   BX-1011             BX          9           100000003           11.1
# 4   BX-1012             BX          6           100000004           12.0
#
#    PRICE
# 0    525
# 1    689
# 2    721
# 3    249
# 4    399

# %%
products.isna().any()
# Out:
# PRODUCTID             False
# PRODCATEGORYID        False
# CREATEDBY             False
# SUPPLIER_PARTNERID    False
# WEIGHTMEASURE         False
# PRICE                 False
# dtype: bool

# %%
products.to_excel("Products.xlsx")

# %%
file_name = "ProductTexts.csv"
folder_name = "Capstone_Project"
percorso = os.getcwd()
producttexts = pd.read_csv(os.path.join(percorso,folder_name,file_name))

# %%
producttexts.head()
# Out:
#   PRODUCTID LANGUAGE       SHORT_DESCR MEDIUM_DESCR  LONG_DESCR
# 0   RO-1001       EN        Roady 1001          NaN         NaN
# 1   RO-1002       EN        Roady 1002          NaN         NaN
# 2   RO-1003       EN        Roady 1003          NaN         NaN
# 3   BX-1011       EN  BMX Vintage 1011          NaN         NaN
# 4   BX-1012       EN     BMX Jump 1012          NaN         NaN

# %%
import numpy as np

# %%
producttexts["DESCRIPTION"] = np.where(producttexts["MEDIUM_DESCR"].isna(), producttexts["SHORT_DESCR"], producttexts["MEDIUM_DESCR"])

# %%
producttexts.head(20)
# Out:
#    PRODUCTID LANGUAGE         SHORT_DESCR               MEDIUM_DESCR  \
# 0    RO-1001       EN          Roady 1001                        NaN
# 1    RO-1002       EN          Roady 1002                        NaN
# 2    RO-1003       EN          Roady 1003                        NaN
# 3    BX-1011       EN    BMX Vintage 1011                        NaN
# 4    BX-1012       EN       BMX Jump 1012                        NaN
# 5    BX-1013       EN      BMX Jump Lux I          BWM Jump Luxury I
# 6    BX-1014       EN     BMX Jump Lux II         BWM Jump Luxury II
# 7    BX-1015       EN          BMX Optima                 BMX Optima
# 8    BX-1016       EN       BMX Optima II              BMX Optima II
# 9    CC-1021       EN       Cyclone Basic                        NaN
# 10   CC-1022       EN       Cyclone Speed                        NaN
# 11   CC-1023       EN         Cyclone III                        NaN
# 12   MB-1031       EN      Mt Discovery B   Mountain Discovery Basic
# ...

# %%
columns_to_drop = ["LANGUAGE", "SHORT_DESCR", "MEDIUM_DESCR", "LONG_DESCR"]
producttexts = producttexts.drop(columns=columns_to_drop)

# %%
producttexts.head()
# Out:
#   PRODUCTID       DESCRIPTION
# 0   RO-1001        Roady 1001
# 1   RO-1002        Roady 1002
# 2   RO-1003        Roady 1003
# 3   BX-1011  BMX Vintage 1011
# 4   BX-1012     BMX Jump 1012

# %%
producttexts.isna().any()
# Out:
# PRODUCTID      False
# DESCRIPTION    False
# dtype: bool

# %%
producttexts.to_excel("ProductTexts.xlsx")

# %%
file_name = "SalesOrderItems.csv"
folder_name = "Capstone_Project"
percorso = os.getcwd()
salesorderitems = pd.read_csv(os.path.join(percorso,folder_name,file_name))

# %%
salesorderitems.head()
# Out:
#    SALESORDERID  SALESORDERITEM PRODUCTID NOTEID CURRENCY  GROSSAMOUNT  \
# 0     500000000              10   MB-1034             USD         2499
# 1     500000000              20   CB-1161             USD          399
# 2     500000001              10   HB-1175             USD          899
# 3     500000001              20   RC-1056             USD         2499
# 4     500000001              30   CC-1021             USD         1144
#
#    NETAMOUNT  TAXAMOUNT ITEMATPSTATUS  OPITEMPOS  QUANTITY QUANTITYUNIT  \
# 0   2186.625    312.375             I        NaN         4           EA
# 1    349.125     49.875             I        NaN         9           EA
# 2    786.625    112.375             I        NaN         2           EA
# 3   2186.625    312.375             I        NaN         2           EA
# 4   1001.000    143.000             I        NaN         3           EA
#
#    DELIVERYDATE
# 0      20180311
# 1      20180311
# 2      20180228
# 3      20180228
# 4      20180228

# %%
columns_to_drop = ["NOTEID", "CURRENCY", "ITEMATPSTATUS", "OPITEMPOS", "QUANTITYUNIT"]
salesorderitems = salesorderitems.drop(columns=columns_to_drop)

# %%
salesorderitems.head()
# Out:
#    SALESORDERID  SALESORDERITEM PRODUCTID  GROSSAMOUNT  NETAMOUNT  TAXAMOUNT  \
# 0     500000000              10   MB-1034         2499   2186.625    312.375
# 1     500000000              20   CB-1161          399    349.125     49.875
# 2     500000001              10   HB-1175          899    786.625    112.375
# 3     500000001              20   RC-1056         2499   2186.625    312.375
# 4     500000001              30   CC-1021         1144   1001.000    143.000
#
#    QUANTITY  DELIVERYDATE
# 0         4      20180311
# 1         9      20180311
# 2         2      20180228
# 3         2      20180228
# 4         3      20180228

# %%
salesorderitems.isna().any()
# Out:
# SALESORDERID      False
# SALESORDERITEM    False
# PRODUCTID         False
# GROSSAMOUNT       False
# NETAMOUNT         False
# TAXAMOUNT         False
# QUANTITY          False
# DELIVERYDATE      False
# dtype: bool

# %%
salesorderitems.to_excel("SalesOrderItems.xlsx")

# %%
file_name = "SalesOrders.csv"
folder_name = "Capstone_Project"
percorso = os.getcwd()
salesorders = pd.read_csv(os.path.join(percorso,folder_name,file_name))

# %%
salesorders.head()
# Out:
#    SALESORDERID  CREATEDBY  CREATEDAT  CHANGEDBY  CHANGEDAT FISCVARIANT  \
# 0     500000000          4   20180111          4   20180116          K4
# 1     500000001          2   20180112          2   20180115          K4
# 2     500000002          5   20180115          5   20180120          K4
# 3     500000003          3   20180115          3   20180120          K4
# 4     500000004          8   20180116          8   20180117          K4
#
#    FISCALYEARPERIOD  NOTEID  PARTNERID SALESORG CURRENCY  GROSSAMOUNT  \
# 0           2018001     NaN  100000022      APJ      USD        13587
# 1           2018001     NaN  100000026     EMEA      USD        12622
# 2           2018001     NaN  100000018      APJ      USD        45655
# 3           2018001     NaN  100000009     EMEA      USD       101786
# 4           2018001     NaN  100000025     EMEA      USD        71684
#
#    NETAMOUNT  TAXAMOUNT LIFECYCLESTATUS BILLINGSTATUS DELIVERYSTATUS
# ...

# %%
columns_to_drop = ["CHANGEDBY", "CHANGEDAT", "FISCVARIANT", "FISCALYEARPERIOD", "NOTEID", "CURRENCY", "LIFECYCLESTATUS", "BILLINGSTATUS", "DELIVERYSTATUS"]
salesorders = salesorders.drop(columns=columns_to_drop)

# %%
salesorders.head()
# Out:
#    SALESORDERID  CREATEDBY  CREATEDAT  PARTNERID SALESORG  GROSSAMOUNT  \
# 0     500000000          4   20180111  100000022      APJ        13587
# 1     500000001          2   20180112  100000026     EMEA        12622
# 2     500000002          5   20180115  100000018      APJ        45655
# 3     500000003          3   20180115  100000009     EMEA       101786
# 4     500000004          8   20180116  100000025     EMEA        71684
#
#    NETAMOUNT  TAXAMOUNT
# 0  11888.625   1698.375
# 1  11044.250   1577.750
# 2  39948.125   5706.875
# 3  89062.750  12723.250
# 4  62723.500   8960.500

# %%
salesorders.isna().any()
# Out:
# SALESORDERID    False
# CREATEDBY       False
# CREATEDAT       False
# PARTNERID       False
# SALESORG        False
# GROSSAMOUNT     False
# NETAMOUNT       False
# TAXAMOUNT       False
# dtype: bool

# %%
salesorders.to_excel("SalesOrders.xlsx")
